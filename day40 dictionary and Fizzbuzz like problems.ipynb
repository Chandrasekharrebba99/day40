# %%
peta = "Kat"
pets = [peta,"puppies"]
print(pets)

peta = peta.replace("k","c")
print(pets)
# Out:
# ['Kat', 'puppies']
# ['Kat', 'puppies']

# %%
t = 0
for i in range(5):
    t+=1
    print(id(t))
# Out:
# 140715769321200
# 140715769321232
# 140715769321264
# 140715769321296
# 140715769321328

# %%
x= ['b','c']
lista = ['a',x]

x+=['d']
a = lista[1]
a[1] = 'd'
print(lista)
# Out:
# ['a', ['b', 'd', 'd']]

# %% [markdown]
# # dictionary frequency count of numbers

# %%
d = {}
arr = [1,2,2,3,3,3,4,4,5,6,6,7,234,2,2,2]
N = len(arr)

count = 1
for i in range(N):
    if arr[i] in d:
        d[arr[i]] +=1
        
    else:
        d[arr[i]] = 1
        
count +=1
    
print(d)
print("Length of array",len(arr))
# Out:
# {1: 1, 2: 5, 3: 3, 4: 2, 5: 1, 6: 2, 7: 1, 234: 1}
# Length of array 16

# %%
maxi = -29388943

for i in d:
    if d[i]>maxi:
        maxi = d[i]
print("Max frequence:",maxi)

for i in d:
    if d[i] == maxi:
        print("Highest frequency number:",i)
# Out:
# Max frequence: 5
# Highest frequency number: 2

# %% [markdown]
# # sumi the frequensi from dictionary

# %%
sumint =0
for i in d:
    sumint  += d[i]
print(sumint)
# Out:
# 16

# %% [markdown]
# # Fizz buzz

# %%
def fizz_buzz(number):
    # Complete this function
    if number%3 == 0 and number%5 ==0:
        print("FizzBuzz")
    elif number%5 ==0:
        print("Buzz")
    elif number%3 == 0:
        print("Fizz")
    else:
        print(number)


number = int(input())
# Call the fizz_buzz function
fizz_buzz(number)
# Out:
# 56
# 56

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
def calculate_bill(amount):
    # Complete this function
    if amount>=2500:
        discount = amount*0.20 
        print(amount-discount)
    elif amount>=500:
        discount = amount*0.10 
        print(amount-discount)
    else:
        discount = amount*0.05
        print(amount-discount)
    


amount = int(input())
# Call the calculate_bill function
calculate_bill(amount)
# Out:
# 1500
# 1350.0

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
def get_discount(amount):
    # Complete this function
    if amount>=2500:
        print("20%")
    elif amount>=500:
        print("10%")
    else:
        print("5%")


amount = int(input())
# Call the get_discount function
get_discount(amount)
# Out:
# 1500
# 10%

# %% [markdown]
# # ![image.png](attachment:image.png)odd = "wcdc"

# %%
def get_weather_report(temperature):
    # Complete this function
    if temperature>=35:
        print("Hot")
    elif temperature>=22:
        print("Warm")
    elif temperature<22:
        print("Cold")


temperature = int(input())
# Call the get_weather_report function
get_weather_report(temperature)
# Out:
# 18
# Cold

# %% [markdown]
# # ![image.png](attachment:image.png)ord("b")

# %%
def get_speed_status(speed):
    # Complete this function
    if speed>=80:
        print("Over Speed")
    elif speed>=60:
        print("Warning")
    elif speed<60:
        print("Normal")
        


speed = int(input())
# Call the get_speed_status function
get_speed_status(speed)
# Out:
# 75
# Warning

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
def calculate_league_points(wins, draws, losses):
    # Complete this function
    total = 0 
    winspoints =0
    drawspoints = 0
    lossespointes = 0
    winspoints = wins*4
    drawspoints = draws*2
    lossespointes = losses*-1
    total = winspoints+drawspoints+lossespointes
    print(total)


statistics = input().split(",")
wins = int(statistics[0])
draws = int(statistics[1])
losses = int(statistics[2])
# Call the calculate_league_points function
calculate_league_points(wins,draws,losses)
# Out:
# 4,1,2
# 16

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
def count_of_lowercase_and_uppercase_letters(arg_1):
    # Complete this function
    count_of_uppercase = 0
    count_of_lowercase = 0
    for i in arg_1:
        if i.isupper():
            count_of_uppercase +=1
        else:
            count_of_lowercase +=1

    print(count_of_uppercase)
    print(count_of_lowercase)


word = input()
# Call the count_of_lowercase_and_uppercase_letters function
count_of_lowercase_and_uppercase_letters(word)
# Out:
# MasTer
# 2
# 4

# %%
string = "scjskd"

# %%
d = set(list(string))

# %%
newstring  = ""
for i in d:
    newstring +=i
print(newstring)
# Out:
# ksdjc

# %%
arr = [1,5,6,6,7,2,2,3,4,4,5,7]
